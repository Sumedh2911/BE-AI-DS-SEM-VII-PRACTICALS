# %%
Name - Sumedh Dilip Dhangar.
Class - BE Artificial Intelligence & Data Science.
Roll No - 15
Title - Data Wrangling. 
       Data Wrangling on Real Estate Market.

# %%
# Step No.1 - Import the Dataset and Clean the Columns name.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\sumedhdhangar\Downloads\Mumbai_Property.csv")

# %%
df.columns
# Out:
# Index(['Property_Name', 'Location', 'Region', 'Property_Age', 'Availability',
#        'Area_Tpye', 'Area_SqFt', 'Rate_SqFt', 'Floor_No', 'Bedroom',
#        'Bathroom', 'Price_Lakh'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace(' ', '_').str.replace('(', '').str.replace(')', '').str.lower()

# %%
df.columns
# Out:
# Index(['property_name', 'location', 'region', 'property_age', 'availability',
#        'area_tpye', 'area_sqft', 'rate_sqft', 'floor_no', 'bedroom',
#        'bathroom', 'price_lakh'],
#       dtype='object')

# %%
df.head()
# Out:
#                   property_name  \
# 0             Omkar Alta Monte
# 1  T Bhimjyani Neelkanth Woods
# 2       Legend 1 Pramila Nagar
# 3              Unnamed Property
# 4              Unnamed Property
#
#                                             location            region  \
# 0                      W E Highway Malad East Mumbai      Malad Mumbai
# 1                               Manpada Thane Mumbai     Manpada Thane
# 2                                Dahisar West Mumbai    Dahisar Mumbai
# 3  Vidyavihar West Vidyavihar West Central Mumbai...    Central Mumbai
# 4  176 Cst Road Kalina Mumbai 400098 Santacruz Ea...  Santacruz Mumbai
#
#    property_age   availability            area_tpye  area_sqft  rate_sqft  \
# 0   0 to 1 Year  Ready To Move  Super Built Up Area     2900.0      17241
# 1   1 to 5 Year  Ready To Move  Super Built Up Area     1900.0      12631
# 2      10+ Year  Ready To Move  Super Built Up Area      595.0      15966
# 3  5 to 10 Year  Ready To Move        Built Up Area     1450.0      25862
# 4  5 to 10 Year  Ready To Move          Carpet Area      876.0      39954
#
#    floor_no  bedroom  bathroom  price_lakh
# 0        14        3         4       500.0
# 1         8        3         3       240.0
# 2         3        1         2        95.0
# 3         1        3         3       375.0
# 4         5        2         2       350.0

# %%
df.tail()
# Out:
#                  property_name                           location  \
# 2575       Shagun White Woods   Sector 23 Ulwe Navi Mumbai Mumbai
# 2576               Guru Anant    Sector 2 Ulwe Navi Mumbai Mumbai
# 2577    Balaji Mayuresh Delta             Ulwe Navi Mumbai Mumbai
# 2578    Balaji Mayuresh Delta             Ulwe Navi Mumbai Mumbai
# 2579  Gurukrupa Tulsi Heights             Ulwe Navi Mumbai Mumbai
#
#                 region property_age   availability      area_tpye  area_sqft  \
# 2575  Ulwe Navi-Mumbai  1 to 5 Year  Ready To Move  Built Up Area     1180.0
# 2576  Ulwe Navi-Mumbai  0 to 1 Year  Ready To Move  Built Up Area     1090.0
# 2577  Ulwe Navi-Mumbai  1 to 5 Year  Ready To Move  Built Up Area     1295.0
# 2578  Ulwe Navi-Mumbai  1 to 5 Year  Ready To Move  Built Up Area     1850.0
# 2579  Ulwe Navi-Mumbai  0 to 1 Year  Ready To Move  Built Up Area     1100.0
#
#       rate_sqft  floor_no  bedroom  bathroom  price_lakh
# 2575      10338         2        2         2       122.0
# 2576       8073        11        2         2        88.0
# 2577      10579         6        2         2       137.0
# 2578       9243         6        3         3       171.0
# 2579       8636         4        2         2        95.0

# %%
# Step No.2 - Handle Missing Values.

# %%
df.isnull().sum()
# Out:
# property_name    0
# location         0
# region           0
# property_age     0
# availability     0
# area_tpye        0
# area_sqft        0
# rate_sqft        0
# floor_no         0
# bedroom          0
# bathroom         0
# price_lakh       0
# dtype: int64

# %%
# Step No.3 - Perform Data Merging.

# %%
additional_df = pd.read_csv(r"C:\Users\saira\Downloads\Cleaned_Mumbai_RealEstate_Data.csv")

# %%
additional_df.columns
# Out:
# Index(['Property_Name', 'Location', 'Region', 'Availability', 'Area_Type',
#        'Area_SqFt', 'Rate_SqFt', 'Floor_No', 'Bedroom', 'Bathroom',
#        'Price_Lakh', 'Property_Age_0 to 1 Year', 'Property_Age_1 to 5 Year',
#        'Property_Age_10+ Year', 'Property_Age_5 to 10 Year',
#        'Property_Age_Under Construction'],
#       dtype='object')

# %%
additional_df.columns = additional_df.columns.str.replace(' ', '_').str.replace('(', '').str.replace(')', '').str.lower()

# %%
additional_df.columns
# Out:
# Index(['property_name', 'location', 'region', 'availability', 'area_type',
#        'area_sqft', 'rate_sqft', 'floor_no', 'bedroom', 'bathroom',
#        'price_lakh', 'property_age_0_to_1_year', 'property_age_1_to_5_year',
#        'property_age_10+_year', 'property_age_5_to_10_year',
#        'property_age_under_construction'],
#       dtype='object')

# %%
df_merged = pd.merge(df, additional_df, on='property_name', how='left')

# %%
df_merged
# Out:
#                    property_name                     location_x  \
# 0              Omkar Alta Monte   W E Highway Malad East Mumbai
# 1              Omkar Alta Monte   W E Highway Malad East Mumbai
# 2              Omkar Alta Monte   W E Highway Malad East Mumbai
# 3              Omkar Alta Monte   W E Highway Malad East Mumbai
# 4              Omkar Alta Monte   W E Highway Malad East Mumbai
# ...                          ...                            ...
# 763428    Balaji Mayuresh Delta         Ulwe Navi Mumbai Mumbai
# 763429    Balaji Mayuresh Delta         Ulwe Navi Mumbai Mumbai
# 763430    Balaji Mayuresh Delta         Ulwe Navi Mumbai Mumbai
# 763431    Balaji Mayuresh Delta         Ulwe Navi Mumbai Mumbai
# 763432  Gurukrupa Tulsi Heights         Ulwe Navi Mumbai Mumbai
#
#                 region_x property_age availability_x            area_tpye  \
# 0           Malad Mumbai  0 to 1 Year  Ready To Move  Super Built Up Area
# 1           Malad Mumbai  0 to 1 Year  Ready To Move  Super Built Up Area
# 2           Malad Mumbai  0 to 1 Year  Ready To Move  Super Built Up Area
# 3           Malad Mumbai  0 to 1 Year  Ready To Move  Super Built Up Area
# 4           Malad Mumbai  0 to 1 Year  Ready To Move  Super Built Up Area
# ...                  ...          ...            ...                  ...
# 763428  Ulwe Navi-Mumbai  1 to 5 Year  Ready To Move        Built Up Area
# 763429  Ulwe Navi-Mumbai  1 to 5 Year  Ready To Move        Built Up Area
# 763430  Ulwe Navi-Mumbai  1 to 5 Year  Ready To Move        Built Up Area
# 763431  Ulwe Navi-Mumbai  1 to 5 Year  Ready To Move        Built Up Area
# 763432  Ulwe Navi-Mumbai  0 to 1 Year  Ready To Move        Built Up Area
#
#         area_sqft_x  rate_sqft_x  floor_no_x  bedroom_x  ...  rate_sqft_y  \
# 0            2900.0        17241          14          3  ...      17241.0
# 1            2900.0        17241          14          3  ...      20238.0
# 2            2900.0        17241          14          3  ...      16220.0
# 3            2900.0        17241          14          3  ...      16466.0
# 4            2900.0        17241          14          3  ...      19404.0
# ...             ...          ...         ...        ...  ...          ...
# 763428       1850.0         9243           6          3  ...      10240.0
# 763429       1850.0         9243           6          3  ...       9569.0
# 763430       1850.0         9243           6          3  ...      10579.0
# 763431       1850.0         9243           6          3  ...       9243.0
# 763432       1100.0         8636           4          2  ...       8636.0
#
#         floor_no_y bedroom_y bathroom_y  price_lakh_y  \
# 0             14.0       3.0        4.0         500.0
# 1              7.0       5.0        5.0         850.0
# 2              4.0       2.0        2.0         212.0
# 3              6.0       3.0        3.0         316.0
# 4             25.0       3.0        3.0         326.0
# ...            ...       ...        ...           ...
# 763428        10.0       2.0        2.0         127.0
# 763429         8.0       3.0        3.0         178.0
# 763430         6.0       2.0        2.0         137.0
# 763431         6.0       3.0        3.0         171.0
# 763432         4.0       2.0        2.0          95.0
#
#         property_age_0_to_1_year  property_age_1_to_5_year  \
# 0                           True                     False
# 1                           True                     False
# 2                          False                      True
# 3                          False                      True
# 4                          False                      True
# ...                          ...                       ...
# 763428                     False                      True
# 763429                     False                      True
# 763430                     False                      True
# 763431                     False                      True
# 763432                      True                     False
#
#         property_age_10+_year  property_age_5_to_10_year  \
# 0                       False                      False
# 1                       False                      False
# 2                       False                      False
# 3                       False                      False
# 4                       False                      False
# ...                       ...                        ...
# 763428                  False                      False
# 763429                  False                      False
# 763430                  False                      False
# 763431                  False                      False
# 763432                  False                      False
#
#         property_age_under_construction
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
# ...                                 ...
# 763428                            False
# 763429                            False
# 763430                            False
# 763431                            False
# 763432                            False
#
# [763433 rows x 27 columns]

# %%
# Step No.4 - Filter and Subset the Data.

# %%
# Filter the data based on location
df_filtered_location = df[df['location'] == 'Sector 23 Ulwe Navi Mumbai Mumbai']

# %%
df_filtered_location.head()
# Out:
#             property_name                           location  \
# 1154        Titanium One   Sector 23 Ulwe Navi Mumbai Mumbai
# 1184     Unnamed Property  Sector 23 Ulwe Navi Mumbai Mumbai
# 1539     Unnamed Property  Sector 23 Ulwe Navi Mumbai Mumbai
# 1584    Platinum Palacio   Sector 23 Ulwe Navi Mumbai Mumbai
# 2529  Shagun White Woods   Sector 23 Ulwe Navi Mumbai Mumbai
#
#                 region property_age   availability            area_tpye  \
# 1154  Ulwe Navi-Mumbai  1 to 5 Year  Ready To Move        Built Up Area
# 1184  Ulwe Navi-Mumbai  0 to 1 Year  Ready To Move          Carpet Area
# 1539  Ulwe Navi-Mumbai  1 to 5 Year  Ready To Move          Carpet Area
# 1584  Ulwe Navi-Mumbai  1 to 5 Year  Ready To Move  Super Built Up Area
# 2529  Ulwe Navi-Mumbai  1 to 5 Year  Ready To Move  Super Built Up Area
#
#       area_sqft  rate_sqft  floor_no  bedroom  bathroom  price_lakh
# 1154      640.0       7500         4        1         2        48.0
# 1184      680.0       9558         2        2         2        65.0
# 1539      680.0       8382         1        2         2        57.0
# 1584      665.0       8307         5        1         1        54.0
# 2529     1160.0      10775         2        2         2       125.0

# %%
df_filtered_location.tail()
# Out:
#             property_name                           location  \
# 1184     Unnamed Property  Sector 23 Ulwe Navi Mumbai Mumbai
# 1539     Unnamed Property  Sector 23 Ulwe Navi Mumbai Mumbai
# 1584    Platinum Palacio   Sector 23 Ulwe Navi Mumbai Mumbai
# 2529  Shagun White Woods   Sector 23 Ulwe Navi Mumbai Mumbai
# 2575  Shagun White Woods   Sector 23 Ulwe Navi Mumbai Mumbai
#
#                 region property_age   availability            area_tpye  \
# 1184  Ulwe Navi-Mumbai  0 to 1 Year  Ready To Move          Carpet Area
# 1539  Ulwe Navi-Mumbai  1 to 5 Year  Ready To Move          Carpet Area
# 1584  Ulwe Navi-Mumbai  1 to 5 Year  Ready To Move  Super Built Up Area
# 2529  Ulwe Navi-Mumbai  1 to 5 Year  Ready To Move  Super Built Up Area
# 2575  Ulwe Navi-Mumbai  1 to 5 Year  Ready To Move        Built Up Area
#
#       area_sqft  rate_sqft  floor_no  bedroom  bathroom  price_lakh
# 1184      680.0       9558         2        2         2        65.0
# 1539      680.0       8382         1        2         2        57.0
# 1584      665.0       8307         5        1         1        54.0
# 2529     1160.0      10775         2        2         2       125.0
# 2575     1180.0      10338         2        2         2       122.0

# %%
df_filtered_property_type = df[(df['area_tpye'] == 'Plot Area') & (df['bedroom'] >2)]

# %%
df_filtered_property_type.head()
# Out:
#         property_name                                           location  \
# 97   Unnamed Property  Ramdev Park Ramdev Park Mira Road And Beyond M...
# 104  Unnamed Property                      New Panvel Navi Mumbai Mumbai
# 183  Unnamed Property                    Wada Mumbai Beyond Thane Mumbai
# 237  Unnamed Property           O 13 Sector 9 Belapur Navi Mumbai Mumbai
# 281  Unnamed Property                 Sector 2 Airoli Navi Mumbai Mumbai
#
#                   region  property_age   availability  area_tpye  area_sqft  \
# 97             Mira Road      10+ Year  Ready To Move  Plot Area     3000.0
# 104   Panvel Navi-Mumbai   0 to 1 Year  Ready To Move  Plot Area      210.0
# 183          Wada Mumbai  5 to 10 Year  Ready To Move  Plot Area     2400.0
# 237  Belapur Navi-Mumbai      10+ Year  Ready To Move  Plot Area     2000.0
# 281   Airoli Navi-Mumbai      10+ Year  Ready To Move  Plot Area     1200.0
#
#      rate_sqft  floor_no  bedroom  bathroom  price_lakh
# 97       18666         4        6         7       560.0
# 104     247619         4        5         4       520.0
# 183       2291         1        3         2        55.0
# 237       8750         2        3         2       175.0
# 281      13750         3        3         2       165.0

# %%
df_filtered_property_type.tail()
# Out:
#             property_name                                           location  \
# 345      Unnamed Property                Sector 9 Belapur Navi Mumbai Mumbai
# 521      Unnamed Property  Sector 1 Koparkhairane Sector 1 Koparkhairane ...
# 567      Unnamed Property                           101 Manpada Thane Mumbai
# 1201  Ravi Gaurav Greens          Mira Road East Mira Road And Beyond Mumbai
# 1984     Unnamed Property                  Khardi Mumbai Beyond Thane Mumbai
#
#                          region  property_age   availability  area_tpye  \
# 345         Belapur Navi-Mumbai      10+ Year  Ready To Move  Plot Area
# 521   Koparkhairane Navi-Mumbai  5 to 10 Year  Ready To Move  Plot Area
# 567               Manpada Thane  5 to 10 Year  Ready To Move  Plot Area
# 1201                  Mira Road  5 to 10 Year  Ready To Move  Plot Area
# 1984               Mumbai Thane      10+ Year  Ready To Move  Plot Area
#
#       area_sqft  rate_sqft  floor_no  bedroom  bathroom  price_lakh
# 345       922.0      27223         2        4         3       251.0
# 521       200.0      34500         3        3         3        69.0
# 567      2700.0      27777         2        4         4       750.0
# 1201   100000.0        290         2        4         4       290.0
# 1984     8500.0       1752         2        3         3       149.0

# %%
# Step No.5 - Handle Categorical Variables.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_name  2580 non-null   object
#  1   location       2580 non-null   object
#  2   region         2580 non-null   object
#  3   property_age   2580 non-null   object
#  4   availability   2580 non-null   object
#  5   area_tpye      2580 non-null   object
#  6   area_sqft      2580 non-null   float64
#  7   rate_sqft      2580 non-null   int64
#  8   floor_no       2580 non-null   int64
#  9   bedroom        2580 non-null   int64
#  10  bathroom       2580 non-null   int64
#  11  price_lakh     2580 non-null   float64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 242.0+ KB

# %%
df['location'].unique()
# Out:
# array(['W E Highway Malad East Mumbai', 'Manpada Thane Mumbai',
#        'Dahisar West Mumbai', ..., '501 Sector 5 Ulwe Navi Mumbai Mumbai',
#        '1503 Mira Road East Mira Road And Beyond Mumbai',
#        'Sector 22 Kamothe Navi Mumbai Mumbai'], dtype=object)

# %%
df['area_tpye'].unique()
# Out:
# array(['Super Built Up Area', 'Built Up Area', 'Carpet Area', 'Plot Area'],
#       dtype=object)

# %%
# Apply One-Hot Encoding to categorical columns
df_encoded = pd.get_dummies(df, columns=['location', 'area_tpye'])

# %%
df_encoded.head()
# Out:
#                   property_name            region  property_age  \
# 0             Omkar Alta Monte       Malad Mumbai   0 to 1 Year
# 1  T Bhimjyani Neelkanth Woods      Manpada Thane   1 to 5 Year
# 2       Legend 1 Pramila Nagar     Dahisar Mumbai      10+ Year
# 3              Unnamed Property    Central Mumbai  5 to 10 Year
# 4              Unnamed Property  Santacruz Mumbai  5 to 10 Year
#
#     availability  area_sqft  rate_sqft  floor_no  bedroom  bathroom  \
# 0  Ready To Move     2900.0      17241        14        3         4
# 1  Ready To Move     1900.0      12631         8        3         3
# 2  Ready To Move      595.0      15966         3        1         2
# 3  Ready To Move     1450.0      25862         1        3         3
# 4  Ready To Move      876.0      39954         5        2         2
#
#    price_lakh  ...  location_Yagna Nagar Mumbai  \
# 0       500.0  ...                        False
# 1       240.0  ...                        False
# 2        95.0  ...                        False
# 3       375.0  ...                        False
# 4       350.0  ...                        False
#
#    location_kavesar Thane Mumbai  \
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
#
#    location_kurla west Central Mumbai suburbs Mumbai  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    location_secter 7 koparkhairne Navi Mumbai Mumbai  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    location_thakurli Mumbai Beyond Thane Mumbai  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    location_y K nagar Nx virar west Mira Road And Beyond Mumbai  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    area_tpye_Built Up Area  area_tpye_Carpet Area  area_tpye_Plot Area  \
# 0                    False                  False                False
# 1                    False                  False                False
# 2                    False                  False                False
# 3                     True                  False                False
# 4                    False                   True                False
#
#    area_tpye_Super Built Up Area
# 0                           True
# 1                           True
# 2                           True
# 3                          False
# 4                          False
#
# [5 rows x 1322 columns]

# %%
from sklearn.preprocessing import LabelEncoder 

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Apply Label Encoding to categorical columns
df['Location_encoded'] = label_encoder.fit_transform(df['location'])
df['Area_Tpye_encoded'] = label_encoder.fit_transform(df['area_tpye'])

# %%
df[['location', 'Location_encoded', 'area_tpye', 'Area_Tpye_encoded']].head()
# Out:
#                                             location  Location_encoded  \
# 0                      W E Highway Malad East Mumbai              1276
# 1                               Manpada Thane Mumbai               886
# 2                                Dahisar West Mumbai               683
# 3  Vidyavihar West Vidyavihar West Central Mumbai...              1263
# 4  176 Cst Road Kalina Mumbai 400098 Santacruz Ea...               246
#
#              area_tpye  Area_Tpye_encoded
# 0  Super Built Up Area                  3
# 1  Super Built Up Area                  3
# 2  Super Built Up Area                  3
# 3        Built Up Area                  0
# 4          Carpet Area                  1

# %%
# Step No.6 - Aggregate the Data.

# %%
# Group by 'Location' and calculate the average sale price
average_price_by_neighborhood = df.groupby('location')['price_lakh'].mean().reset_index()
average_price_by_neighborhood
# Out:
#                                                location  price_lakh
# 0                                 000 4 Bunglows Mumbai    700.0000
# 1                          000 Anand Nagar Thane Mumbai     69.0000
# 2                               000 Andheri West Mumbai    450.0000
# 3                               000 Balkum Thane Mumbai    210.0000
# 4                              000 Borivali West Mumbai    102.0000
# ...                                                 ...         ...
# 1303                               kavesar Thane Mumbai    120.3750
# 1304           kurla west Central Mumbai suburbs Mumbai    156.6000
# 1305           secter 7 koparkhairne Navi Mumbai Mumbai    110.0000
# 1306                thakurli Mumbai Beyond Thane Mumbai     61.5125
# 1307  y K nagar Nx virar west Mira Road And Beyond M...     38.0000
#
# [1308 rows x 2 columns]

# %%
# Group by 'area_Tpye' and calculate the average sale price
average_price_by_area_type = df.groupby('area_tpye')['price_lakh'].mean().reset_index()
average_price_by_area_type
# Out:
#              area_tpye  price_lakh
# 0        Built Up Area  138.621000
# 1          Carpet Area  184.005299
# 2            Plot Area  215.687500
# 3  Super Built Up Area  177.751004

# %%
# Step No.7 - Identify and Handle Outliers.

# %%
from scipy import stats

# Calculate Z-scores
z_scores = stats.zscore(df['price_lakh'])
df['z_score'] = z_scores

# %%
z_scores
# Out:
# 0       0.881426
# 1       0.177607
# 2      -0.214908
# 3       0.543052
# 4       0.475377
#           ...
# 2575   -0.141819
# 2576   -0.233857
# 2577   -0.101214
# 2578   -0.009176
# 2579   -0.214908
# Name: price_lakh, Length: 2580, dtype: float64

# %%
# Identify outliers (e.g., Z-score > 3 or < -3)
outliers_z_score = df[(df['z_score'] > 3) | (df['z_score'] < -3)]

# Display outliers
outliers_z_score
# Out:
#                             property_name  \
# 39                   Swan Lake Apartment
# 203                          Sagar Mahal
# 329                Jolly Maker Apartment
# 605   Hiranandani Gardens Richmond Tower
# 634                  Kalpataru Solitaire
# 635                  Kalpataru Solitaire
# 1064                     Unnamed Property
# 1067                     Unnamed Property
# 1416                     Unnamed Property
# 1675                      Piramal Aranya
# 2065                          White City
#
#                                                location             region  \
# 39             1 101 Khar West Mumbai South West Mumbai       South Mumbai
# 203   Opposite Gopi Birla School And Sheetal Baug Wa...  Walkeshwar Mumbai
# 329                    Cuffe Parade South Mumbai Mumbai       South Mumbai
# 605   Hiranandani Gardens Powai Hiranandani Gardens ...     Central Mumbai
# 634                       Juhu Mumbai South West Mumbai        Juhu Mumbai
# 635                       Juhu Mumbai South West Mumbai        Juhu Mumbai
# 1064                      Juhu Mumbai South West Mumbai        Juhu Mumbai
# 1067                      Juhu Mumbai South West Mumbai        Juhu Mumbai
# 1416                      Juhu Mumbai South West Mumbai        Juhu Mumbai
# 1675    Byculla East Byculla East Mumbai Harbour Mumbai     Mumbai Harbour
# 2065                          005 Kandivali East Mumbai   Kandivali Mumbai
#
#      property_age   availability            area_tpye  area_sqft  rate_sqft  \
# 39       10+ Year  Ready To Move          Carpet Area     2715.0      66298
# 203      10+ Year  Ready To Move        Built Up Area     2450.0      67350
# 329      10+ Year  Ready To Move        Built Up Area     2135.0      74941
# 605   1 to 5 Year  Ready To Move  Super Built Up Area     5000.0      33000
# 634   1 to 5 Year  Ready To Move  Super Built Up Area     3000.0      46000
# 635   1 to 5 Year  Ready To Move  Super Built Up Area     2800.0      46428
# 1064     10+ Year  Ready To Move        Built Up Area     4363.0      36672
# 1067     10+ Year  Ready To Move  Super Built Up Area     4200.0      45238
# 1416     10+ Year  Ready To Move  Super Built Up Area     5700.0      42105
# 1675  0 to 1 Year  Ready To Move          Carpet Area     2800.0      49107
# 2065  0 to 1 Year  Ready To Move  Super Built Up Area     1000.0    1650000
#
#       floor_no  bedroom  bathroom  price_lakh  Location_encoded  \
# 39           0        4         4      1800.0                69
# 203          9        4         5      1650.0               991
# 329         20        5         4      1600.0               673
# 605          6        5         6      1650.0               766
# 634          6        3         5      1380.0               781
# 635          5        3         3      1300.0               781
# 1064         2        4         4      1600.0               781
# 1067         1        4         4      1900.0               781
# 1416         1        4         4      2400.0               781
# 1675        21        4         4      1375.0               637
# 2065        21        2         2     16500.0                60
#
#       Area_Tpye_encoded    z_score
# 39                    1   4.400525
# 203                   0   3.994475
# 329                   0   3.859125
# 605                   3   3.994475
# 634                   3   3.263586
# 635                   3   3.047026
# 1064                  0   3.859125
# 1067                  3   4.671225
# 1416                  3   6.024724
# 1675                  1   3.250051
# 2065                  3  44.193409

# %%
# Remove outliers based on Z-scores
df_cleaned = df[(df['z_score'] <= 3) & (df['z_score'] >= -3)]

# Drop the Z-score column if no longer needed
df_cleaned = df_cleaned.drop(columns=['z_score'])

# %%
df_cleaned.head()
# Out:
#                   property_name  \
# 0             Omkar Alta Monte
# 1  T Bhimjyani Neelkanth Woods
# 2       Legend 1 Pramila Nagar
# 3              Unnamed Property
# 4              Unnamed Property
#
#                                             location            region  \
# 0                      W E Highway Malad East Mumbai      Malad Mumbai
# 1                               Manpada Thane Mumbai     Manpada Thane
# 2                                Dahisar West Mumbai    Dahisar Mumbai
# 3  Vidyavihar West Vidyavihar West Central Mumbai...    Central Mumbai
# 4  176 Cst Road Kalina Mumbai 400098 Santacruz Ea...  Santacruz Mumbai
#
#    property_age   availability            area_tpye  area_sqft  rate_sqft  \
# 0   0 to 1 Year  Ready To Move  Super Built Up Area     2900.0      17241
# 1   1 to 5 Year  Ready To Move  Super Built Up Area     1900.0      12631
# 2      10+ Year  Ready To Move  Super Built Up Area      595.0      15966
# 3  5 to 10 Year  Ready To Move        Built Up Area     1450.0      25862
# 4  5 to 10 Year  Ready To Move          Carpet Area      876.0      39954
#
#    floor_no  bedroom  bathroom  price_lakh  Location_encoded  \
# 0        14        3         4       500.0              1276
# 1         8        3         3       240.0               886
# 2         3        1         2        95.0               683
# 3         1        3         3       375.0              1263
# 4         5        2         2       350.0               246
#
#    Area_Tpye_encoded
# 0                  3
# 1                  3
# 2                  3
# 3                  0
# 4                  1
